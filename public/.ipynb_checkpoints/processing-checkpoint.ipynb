# %%
import pandas as pd

# %%
countries = pd.read_json('map.geo.json')
countries
# Out:
#                   type                                           features
# 0    FeatureCollection  {'type': 'Feature', 'properties': {'featurecla...
# 1    FeatureCollection  {'type': 'Feature', 'properties': {'featurecla...
# 2    FeatureCollection  {'type': 'Feature', 'properties': {'featurecla...
# 3    FeatureCollection  {'type': 'Feature', 'properties': {'featurecla...
# 4    FeatureCollection  {'type': 'Feature', 'properties': {'featurecla...
# ..                 ...                                                ...
# 253  FeatureCollection  {'type': 'Feature', 'properties': {'featurecla...
# 254  FeatureCollection  {'type': 'Feature', 'properties': {'featurecla...
# 255  FeatureCollection  {'type': 'Feature', 'properties': {'featurecla...
# 256  FeatureCollection  {'type': 'Feature', 'properties': {'featurecla...
# 257  FeatureCollection  {'type': 'Feature', 'properties': {'featurecla...
#
# [258 rows x 2 columns]

# %%
import geopandas as gpd

# %%
countries = gpd.read_file('map.geo.json')
countries
# Out:
#           featurecla  scalerank  labelrank      sovereignt sov_a3  adm0_dif  \
# 0    Admin-0 country          0          5      Costa Rica    CRI         0
# 1    Admin-0 country          0          5       Nicaragua    NIC         0
# 2    Admin-0 country          3          6          France    FR1         1
# 3    Admin-0 country          3          6     Netherlands    NL1         1
# 4    Admin-0 country          0          5           Haiti    HTI         0
# ..               ...        ...        ...             ...    ...       ...
# 253  Admin-0 country          3          5       Mauritius    MUS         0
# 254  Admin-0 country          5          5  United Kingdom    GB1         1
# 255  Admin-0 country          5          5        Maldives    MDV         0
# 256  Admin-0 country          3          4  United Kingdom    GB1         1
# 257  Admin-0 country          6          5          France    FR1         1
#
# ...

# %%
csv_file_path = 'API_SP.POP.TOTL_DS2_en_csv_v2_85.csv'
population_df = pd.read_csv(csv_file_path, skiprows=4, header=0)
population_df
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# ...

# %%
years_of_interest = ['Country Name', '2022','2021','2020', '2019', '2018']  
population_df_selected = population_df[years_of_interest]

# %%
gdf_merged = countries.merge(population_df_selected, left_on='admin', right_on='Country Name', how='left')
gdf_merged
# Out:
#           featurecla  scalerank  labelrank      sovereignt sov_a3  adm0_dif  \
# 0    Admin-0 country          0          5      Costa Rica    CRI         0
# 1    Admin-0 country          0          5       Nicaragua    NIC         0
# 2    Admin-0 country          3          6          France    FR1         1
# 3    Admin-0 country          3          6     Netherlands    NL1         1
# 4    Admin-0 country          0          5           Haiti    HTI         0
# ..               ...        ...        ...             ...    ...       ...
# 253  Admin-0 country          3          5       Mauritius    MUS         0
# 254  Admin-0 country          5          5  United Kingdom    GB1         1
# 255  Admin-0 country          5          5        Maldives    MDV         0
# 256  Admin-0 country          3          4  United Kingdom    GB1         1
# 257  Admin-0 country          6          5          France    FR1         1
#
# ...

# %%
gdf_merged[['admin','2018','2019','2020','2021','2022']]
# Out:
#                               admin        2018        2019        2020  \
# 0                        Costa Rica   5040734.0   5084532.0   5123105.0
# 1                         Nicaragua   6572233.0   6663924.0   6755895.0
# 2                      Saint Martin         NaN         NaN         NaN
# 3                      Sint Maarten         NaN         NaN         NaN
# 4                             Haiti  11012421.0  11160438.0  11306801.0
# ..                              ...         ...         ...         ...
# 253                       Mauritius   1265577.0   1265985.0   1266014.0
# 254  British Indian Ocean Territory         NaN         NaN         NaN
# 255                        Maldives    489758.0    504508.0    514438.0
# 256   South Georgia and the Islands         NaN         NaN         NaN
# 257               Clipperton Island         NaN         NaN         NaN
#
#            2021        2022
# 0     5153957.0   5180829.0
# 1     6850540.0   6948392.0
# ...

# %%
countries = ', '.join(gdf_merged['admin'])
